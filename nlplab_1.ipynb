# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshul-ARK/nlp_lab_assignments/blob/main/nlplab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from datasets import load_dataset

dt = load_dataset("ai4bharat/IndicCorpV2", "indiccorp_v2", split ="tel_Telu",streaming=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]

# %%
#this is the sample data inside the telugu dataset

# %%
# print(type(dt))
# dt.shape
#take some 10000 lines inside the telugu dataset

# %%
# Take the first 10000 lines from the dataset
sample_data = list(dt.take(5000))

# %%
import re
#. ? !
pattern = r'^.*[.?!]$'
#now i have the pattern for it
# arr = re.findall(pattern,sample_data)
arr = []
for i in sample_data:
  arr.append(re.findall(pattern,i['text']));
print(len(arr))
# print(arr)
arr2 = []
for i in arr:
  if(len(i) != 0):
    arr2.append(i)
# print(len(arr2))
print(arr2)
# Out:
# 5000
# ...

# %%
#now i have the sentences inside the
#arr2 contains the sentence tokenizer
arr3 = []
#arr3 will be the word tokenizer inside this code
#now the question is how to handle the links and the emails and the date
#we can first search for the date
#then we can search for the email
#then we can handle the links
#we should also handle the numbers
#then we will take care abt the remaining telugu words
#taking both the american and the indian format dates into consideration
#indian format DD/MM/YYYY
#american format MM/DD/YYYY

# %%
#handling the indian format data
#now we should add the custom logic for the date_reg
#writing simple reg for indian assuming we dont have any noise
date_reg = r'(\d{2}/\d{2}/\d{4})|(\d{2}-(?:\w+)-\d{4})'
#simepl date regex
date_list = []
for i in arr2:
  date_list.append(re.findall(date_reg,i[0]))
print(date_list)
# print(type(arr2[0]))
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [
# ...

# %%
#handle the noise for indian here

# %%
#handle the emails from the code
#how are the emails in the form
#@gmail.com
#local@domain
email_pattern = r'\w+@(?:(?:(?:\w)+\.)+)\w{2,}'
email_pa2 = r'\w+@(?:\w+\.)+\w{2,}'
#there are some changes to be done to the regex
email_list = []
for i in arr2:
  email_list.append(re.findall(email_pa2,i[0]))
print(email_list)
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [
# ...

# %%
#now going to handle all the number related things
#we should take care of the decimal number too

pattern_nums = r'\d+\.\d+|\d+'
#the above regex matches if the pattern contains float or normal integers
numbers_lists = []
for i in arr2:
  numbers_lists.append(re.findall(pattern_nums,i[0]));
print(numbers_lists)

# i have to elimiante the null or zero size values also
# Out:
# [[], ['2'], [], [], [], [], ['2021', '13'], [], [], [], ['1', '36', '732', '1539'], [], ['22'], [], [], [], ['1'], [], [], [], [], ['50'], [], [], [], ['18'], ['3', '710', '1', '120', '12', '24'], [], ['5', '30'], ['2', '60', '249', '200'], ['4'], ['281'], ['100'], [], ['6', '570', '4', '514'], [], [], [], [], [], [], [], [], [], ['10'], [], [], [], [], [], ['2010'], [], [], [], [], [], [], [], [], [], [], [], ['8', '2'], ['2014'], [], [], [], ['400'], [], ['15', '12', '6', '2'], [], [], [], [], [], [], [], ['2'], ['1'], [], [], [], [], [], [], ['25', '25', '11'], ['24', '19', '35', '15'], [], [], [], [], [], [], [], ['5', '10', '23', '46', '2'], [], [], ['258', '45'], [], [], [], [], [], ['6', '6'], ['42', '18', '2014', '23'], ['2014'], [], [], ['15'], [], ['4'], [], [], [], ['300'], [], ['5', '10', '10', '5', '5', '10', '10', '5', '10', '10'], [], [], [], [], ['150', '200', '400'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['9'], ['5', '10', '5', '10', '10', '10'], []
# ...

# %%
#here going to handle all the url related stuff here
#how does a url looks like
#write the regex for simple url
# url_pattern = r'https://(\w+)\.com|http://(\w+)\.com'
url_pattern = r'https?://([\w.-]+)\.com'
url_pattern_list = []
for i in arr2:
  url_pattern_list.append(re.findall(url_pattern,i[0]))
print(url_pattern_list)
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [
# ...

# %%
#save all the values inside different csv files or smthg

# %%
#here i have to calculate everything
#count the no of words
#count the total no of characters
#avg sentence length
#avg word length
#type/token ratio
arr5 = []
pattern6 = r'[\u0C00-\u0C7F]+'
for i in arr2:
  arr5.append(re.findall(pattern6,i[0]));
print(arr5)
# Out:
# [['అమెరికా', 'అధ్యక్షుడు', 'డొనాల్డ్', 'ట్రంప్', 'కు', 'రాష్ట్రపతి', 'భవన్', 'వద్ద', 'ఘనస్వాగతం', 'లభించింది', 'ఆయనకు', 'రాష్ట్రపతి', 'రామ్', 'నాథ్', 'కోవింద్', 'దంపతులు', 'ప్రధాని', 'మోదీ', 'సాదరంగా', 'ఆహ్వానం', 'పలకడంతో', 'పాటు', 'సైనికులు', 'గౌరవ', 'వందనాన్ని', 'అందించారు'], ['ఇటు', 'తెలంగాణలో', 'కరోనా', 'వైరస్', 'కారణంగా', 'అన్ని', 'దేవాలయాల్లో', 'ముందస్తు', 'చర్యలు', 'చేపట్టారు', 'భద్రాద్రి', 'రాముడికి', 'కరోనా', 'ఎఫెక్ట్', 'తగిలింది', 'ఏప్రిల్', 'న', 'భద్రాద్రిలో', 'జరగనున్న', 'శ్రీరామ', 'నవమి', 'వేడుకలను', 'వెంటాడుతోంది', 'కరోనా', 'రాష్ట్రంలో', 'కొనసాగుతున్న', 'కరోనా', 'అలర్ట్', 'నేపథ్యంలో', 'భక్తులు', 'లేకుండానే', 'శ్రీరామనవమి', 'జరుపుతామని', 'మంత్రి', 'పువ్వాడ', 'అజయ్', 'పేర్కొన్నారు', 'ప్రత్యేక', 'మీడియా', 'సమావేశం', 'ఏర్పాటు', 'చేసిన', 'మంత్రి', 'పువ్వాడ', 'ఈ', 'మేరకు', 'స్పష్టం', 'చేశారు', 'శ్రీ', 'రాములవారి', 'కల్యాణం', 'టికెట్లు', 'రద్దు', 'చేస్తున్నామని', 'ప్రకటించారు', 'టికెట్', 'డబ్బు', 'తిరిగి', 'ఆలయ', 'అధికారులు', 'చెల్లిస్తారన్నారు', 'కరోనాపై', 'ప్రజలు', 'భయభ్రాంత
# ...

# %%
#counting total number of characters
arr6 = []
patt = r'[\u0C00-\u0C7F]'
for i in arr5:
  for j in i:
    arr6.append(re.findall(patt,j))
print(arr6)
#doubt is that what should we do with the
# Out:
# [['అ', 'మ', 'ె', 'ర', 'ి', 'క', 'ా'], ['అ', 'ధ', '్', 'య', 'క', '్', 'ష', 'ు', 'డ', 'ు'], ['డ', 'ొ', 'న', 'ా', 'ల', '్', 'డ', '్'], ['ట', '్', 'ర', 'ం', 'ప', '్'], ['క', 'ు'], ['ర', 'ా', 'ష', '్', 'ట', '్', 'ర', 'ప', 'త', 'ి'], ['భ', 'వ', 'న', '్'], ['వ', 'ద', '్', 'ద'], ['ఘ', 'న', 'స', '్', 'వ', 'ా', 'గ', 'త', 'ం'], ['ల', 'భ', 'ి', 'ం', 'చ', 'ి', 'ం', 'ద', 'ి'], ['ఆ', 'య', 'న', 'క', 'ు'], ['ర', 'ా', 'ష', '్', 'ట', '్', 'ర', 'ప', 'త', 'ి'], ['ర', 'ా', 'మ', '్'], ['న', 'ా', 'థ', '్'], ['క', 'ో', 'వ', 'ి', 'ం', 'ద', '్'], ['ద', 'ం', 'ప', 'త', 'ు', 'ల', 'ు'], ['ప', '్', 'ర', 'ధ', 'ా', 'న', 'ి'], ['మ', 'ో', 'ద', 'ీ'], ['స', 'ా', 'ద', 'ర', 'ం', 'గ', 'ా'], ['ఆ', 'హ', '్', 'వ', 'ా', 'న', 'ం'], ['ప', 'ల', 'క', 'డ', 'ం', 'త', 'ో'], ['ప', 'ా', 'ట', 'ు'], ['స', 'ై', 'న', 'ి', 'క', 'ు', 'ల', 'ు'], ['గ', 'ౌ', 'ర', 'వ'], ['వ', 'ం', 'ద', 'న', 'ా', 'న', '్', 'న', 'ి'], ['అ', 'ం', 'ద', 'ి', 'ం', 'చ', 'ా', 'ర', 'ు'], ['ఇ', 'ట', 'ు'], ['త', 'ె', 'ల', 'ం', 'గ', 'ా', 'ణ', 'ల', 'ో'], ['క', 'ర', 'ో', 'న', 
# ...

# %%
#avg sentence length
avg_sen_len = 0
for i in arr2:
  avg_sen_len += len(i[0])
print(avg_sen_len/len(arr2))
# Out:
# 326.3465703971119

# %%
#avg word length
avg_word_len = 0
for i in arr5:
  avg_word_len += len(i)
print(avg_word_len/len(arr5))
# Out:
# 41.7942238267148

# %%
#type/token ratio
cnt7 = 0
st = set()
for i in arr5:
  for j in i:
     st.add(j)
     cnt7 += 1
print(len(st)/len(arr5))
# Out:
# 13.21763795771016

# %%
#this is taken from the chatgpt-4
import csv

# Flatten the list of lists `arr2` into a single list of strings
flattened_sentences = [sentence[0] for sentence in arr2 if sentence]

# Specify the output CSV file path
csv_file_path = 'sentences.csv'

# Write the sentences to the CSV file
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
    csv_writer = csv.writer(csvfile)
    for sentence in flattened_sentences:
        csv_writer.writerow([sentence])

print(f"Sentences saved to {csv_file_path}")
# Out:
# Sentences saved to sentences.csv
